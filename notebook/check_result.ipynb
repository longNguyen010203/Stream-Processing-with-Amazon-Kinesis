# %%
import pandas as pd

# %%
URL ="/home/longnguyen/Documents/Coding/Workshop-AWS/stream-processing-with-amz-kinesis/data/KDS-S3-StockTrade-1-2024-09-30-17-53-33-dc45bdaa-56b2-4ce8-97cf-a21bbfd877ec.json"

# %%
URL2="/home/longnguyen/Documents/Coding/Workshop-AWS/stream-processing-with-amz-kinesis/data/KDS-S3-StockTrade-1-2024-10-01-18-42-50-a3f88b7a-6a97-4ddf-884b-c40c7d542e6a.json"

# %%
URL3="/home/longnguyen/Documents/Coding/Workshop-AWS/stream-processing-with-amz-kinesis/data/KDS-S3-StockStream-1-2024-10-02-23-48-24-b39a8072-8e75-4f07-bf31-18050c82d3e8.json"

# %%
URL4="/home/longnguyen/Documents/Coding/Workshop-AWS/stream-processing-with-amz-kinesis/data/KDS-S3-StockStream-1-2024-10-03-09-44-18-0d7000ab-bea2-40e7-ae27-4c86d481beff.json"

# %%
df = pd.read_json(URL4, lines=True)

# %%
df.head(30)
# Out:
#    tradeType      price  quantity  id stockId            tradeTime
# 0        BUY      65.06      2891   1   RDS.A  2024-10-03 09:45:20
# 1        BUY     114.49      8591   2     PTR  2024-10-03 09:45:20
# 2       SELL     552.13      6863   3    GOOG  2024-10-03 09:45:20
# 3        BUY     100.49       673   4     NVS  2024-10-03 09:45:20
# 4       SELL      93.60      9074   5      PG  2024-10-03 09:45:20
# 5        BUY      25.81      4180   6      GE  2024-10-03 09:45:20
# 6        BUY      31.34      2113   7     PFE  2024-10-03 09:45:20
# 7       SELL     115.38      6347   8     BUD  2024-10-03 09:45:20
# 8       SELL      53.65      5845   9     WFC  2024-10-03 09:45:20
# 9        BUY     129.72      7772  10    AAPL  2024-10-03 09:45:20
# 10      SELL      68.67      3694  11      PG  2024-10-03 09:45:20
# 11       BUY  228328.95      1551  12   BRK.A  2024-10-03 09:45:20
# 12       BUY      94.81      5937  13     PTR  2024-10-03 09:45:20
# ...

# %%
df.shape
# Out:
# (225, 6)

# %%
df.head(20)
# Out:
#     attemptsMade  arrivalTimestamp              errorCode  \
# 0              1     1727806761834  Decompression failed.
# 1              1     1727806762904  Decompression failed.
# 2              1     1727806763989  Decompression failed.
# 3              1     1727806765079  Decompression failed.
# 4              1     1727806766177  Decompression failed.
# 5              1     1727806767265  Decompression failed.
# 6              1     1727806768352  Decompression failed.
# 7              1     1727806769447  Decompression failed.
# 8              1     1727806770537  Decompression failed.
# 9              1     1727806771614  Decompression failed.
# 10             1     1727806772683  Decompression failed.
# 11             1     1727806773747  Decompression failed.
# 12             1     1727806774837  Decompression failed.
# 13             1     1727806775905  Decompression failed.
# 14             1     1727806777032  Decompression failed.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tickerSymbol  107 non-null    object
#  1   tradeType     107 non-null    object
#  2   price         107 non-null    float64
#  3   quantity      107 non-null    int64
#  4   id            107 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.3+ KB
